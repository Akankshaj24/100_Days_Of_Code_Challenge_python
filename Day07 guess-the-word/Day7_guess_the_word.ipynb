# %%
word_list = ['abruptly','absurd','abyss','affix','askew','avenue','awkward','axiom','azure','bagpipes','bandwagon','banjo','bayou','beekeeper','bikini','blitz',
'blizzard','boggle','bookworm','boxcar','boxful','buckaroo','buffalo','buffoon','buxom','buzzard','buzzing','buzzwords','caliph','cobweb','cockiness','croquet',
'crypt','curacao','cycle','daiquiri','dirndl','disavow','dizzying','duplex','dwarves','embezzle','equip','espionage','euouae','exodus','faking','fishhook','fixable',
'fjord','flapjack','flopping','fluffiness','flyby','foxglove','frazzled','frizzled','fuchsia','funny','gabby','galaxy','galvanize','gazebo','giaour','gizmo','glowworm',
'glyph','gnarly','gnostic','gossip','grogginess','haiku','haphazard','hyphen','iatrogenic','icebox','injury','ivory','ivy','jackpot','jaundice','jawbreaker','jaywalk',
'jazziest','jazzy','jelly','jigsaw','jinx','jiujitsu','jockey','jogging','joking','jovial','joyful','juicy','jukebox','jumbo','kayak','kazoo','keyhole','khaki','kilobyte',
'kiosk','kitsch','kiwifruit','klutz','knapsack','larynx','lengths','lucky','luxury','lymph','marquis','matrix','megahertz','microwave','mnemonic','mystify','naphtha',
'nightclub','nowadays','numbskull','nymph','onyx','ovary','oxidize','oxygen','pajama','peekaboo','phlegm','pixel','pizazz','pneumonia','polka','pshaw','psyche','puppy',
'puzzling','quartz','queue','quips','quixotic','quiz','quizzes','quorum','razzmatazz','rhubarb','rhythm','rickshaw','schnapps','scratch','shiv','snazzy','sphinx','spritz',
'squawk','staff','strength','strengths','stretch','stronghold','stymied','subway','swivel','syndrome','thriftless','thumbscrew','topaz','transcript','transgress','transplant',
'triphthong','twelfth','twelfths','unknown','unworthy','unzip','uptown','vaporize','vixen','vodka','voodoo','vortex','voyeurism','walkway','waltz','wave','wavy','waxy',
'wellspring','wheezy','whiskey','whizzing','whomever','wimpy','witchcraft','wizard','woozy','wristwatch','wyvern','xylophone','yachtsman','yippee','yoked','youthful',
'yummy','zephyr','zigzag','zigzagging','zilch','zipper','zodiac', 'zombie']

# %%
print('-'*20)
print('*'*8,"INSTRUCTIONS",'*'*8)
print('Welcome to the game: GUESS THE WORD')
print('You got total 15 guesses to find the word correctly')
print('For a wrong guess number of Guesses reduced by ONE')
print('-'*20)
import random
word=random.choice(word_list)
print('Guess the word : ')
wordLen = len(word)
guessedWord=[]
for i in word:
    guessedWord.append('_')
print(guessedWord)
chances = 12
end_of_the_game = False
while not end_of_the_game:
    print(f'\nNumber of chances left: {chances}')
    guessedLetter = input('Guess the letter?\n').lower()
    if guessedLetter in guessedWord:
        print(f'You already guessed letter {guessedLetter}')
    if guessedLetter not in word:
        chances-=1
        # print(f'Number of chances left: {chances}')
        print(f'Wrong Guess {guessedLetter}')
        if chances==0:
            end_of_the_game=True
            print('Try luck next time...')
    for i in range (wordLen):
        if word[i]==guessedLetter:
            guessedWord[i]=guessedLetter
    print(guessedWord)

    if '_' not in guessedWord:
        end_of_the_game = True
        print('You guessed word correctly you won the game!!!')

print(f'The word was : {word}')
# Out:
# --------------------
# ******** INSTRUCTIONS ********
# Welcome to the game: GUESS THE WORD
# You got total 15 guesses to find the word correctly
# For a wrong guess number of Guesses reduced by ONE
# --------------------
# Guess the word :
# ['_', '_', '_', '_', '_', '_', '_', '_']
#
# Number of chances left: 12
# Guess the letter?
# s
# Wrong Guess s
# ['_', '_', '_', '_', '_', '_', '_', '_']
#
# Number of chances left: 11
# Guess the letter?
# m
# Wrong Guess m
# ['_', '_', '_', '_', '_', '_', '_', '_']
#
# Number of chances left: 10
# Guess the letter?
# a
# Wrong Guess a
# ['_', '_', '_', '_', '_', '_', '_', '_']
#
# Number of chances left: 9
# Guess the letter?
# q
# Wrong Guess q
# ['_', '_', '_', '_', '_', '_', '_', '_']
#
# Number of chances left: 8
# Guess the letter?
# i
# Wrong Guess i
# ['_', '_', '_', '_', '_', '_', '_', '_']
#
# Number of chances left: 7
# Guess the letter?
# e
# ['_', '_', '_', '_', '_', '_', '_', 'e']
#
# Number of chances left: 7
# ...
